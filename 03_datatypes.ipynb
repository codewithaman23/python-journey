# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data Types are classification of the data that tells and compiler and interpreter that what kinds of value we can store into a variable and how much amount of memory will be consumed to store that data and the operations it can perform

# %%
age = (input('Enter the age:'))

# %%
age
# Out:
# '23'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age2 = 40

# %%
age2
# Out:
# 40

# %%
print(age+age2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(age+age2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age2 = 'Hello'

# %%
print(age+age2)   # string + string = concnate
# Out:
# 23Hello

# %%
a = str()

# %%
type(a)
# Out:
# str

# %% [markdown]
# # Different types of Data Types

# %% [markdown]
# 1. int
# 2. str.
# 3. bool
# 4. float

# %%
a = 23
type(a)
# Out:
# int

# %%
b = 'Aman'

# %%
type(b)
# Out:
# str

# %%
c = 14.4

# %%
type(c)
# Out:
# float

# %%
is_true = True

# %%
type(is_true)
# Out:
# bool

# %%
a = 7
b = 7

a==b
# Out:
# True

# %%
a = 12
b = 14

a==b
# Out:
# False
