# %% [markdown]
# Python is a Type of programming language which we can use for communicating with computer or technology.

# %% [markdown]
# Syntax for Python Language

# %% [markdown]
# Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured programs in a language.

# %% [markdown]
# # Semantics of Python Language

# %% [markdown]
# Semantics of Python Language refers to the meaning or interpretation of symbols, characters and commands in a language. It is about what the code is supposed to do when it runs

# %% [markdown]
# # Python Syntax Rule

# %% [markdown]
# 1. Python is case sensitive

# %%
name = 'Aman'
Name = 'Aman'
name==Name
# Out:
# True

# %%
name = 'Aman'
Name = 'aman'
name==Name
# Out:
# False

# %% [markdown]
# # Indentation in Python

# %% [markdown]
# In other programming langauge, we use {} for grouping of statements
# In python, we use Indentation for proper grouping of statements as the proper arrangement of statements with proper spacing in the statements with a block. It simply Indentation means the other programer when see your code it can easily understandable

# %%
age = int(input('Enter your age'))
if age > 18:
    print('Your are eligible for driving')
# Out:
# Your are eligible for driving

# %%
1+2+3+4+5+6+7+\
      6+7
# Out:
# 41

# %% [markdown]
# Line Continuation -> We can use Blackslach for continuing the statement on the next line

# %% [markdown]
# # Multiple Statements in a single line in Python

# %%
a=4;
b=7;

# %%
a=4 b=7
# Out:
#   Cell In[9], line 1
#     a=4 b=7
#         ^
# SyntaxError: invalid syntax

# %%
a=4 ; b = 7 ; c =7

# %% [markdown]
# Using semicolen (;) we can right multiple statements in one line
