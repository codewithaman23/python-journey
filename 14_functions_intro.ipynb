# %% [markdown]
# # Functions

# %% [markdown]
# ## A function is a block of code that performs a specific task.
#
# ## Functions helps in Organizing code, Reusing code and improving readability.

# %% [markdown]
# ## Syntax for function
#
# ##### def function_name(parameter):
#       #####''' Docstring '''
#       ##### #function Body
#      ##### return expression

# %%
# We are creating a function to see how the translation is going to be their from english to hindi language

def translator(English_text):
    """This function is going to be used for converting the english language into hidi langauge"""
    if English_text == 'Hello' or English_text == 'hello':
        print(f"The translator for {English_text} is Namaste")

    if English_text == 'Help' or English_text == help:
        print(f"The translator for {English_text} is Madad")

    if English_text == 'Required' or English_text == 'required':
        print(f'The translation for {English_text} is Aavashyak')

# %% [markdown]
# ## For having the access to our Function and to provide the input to our function we can simpally call the function

# %% [markdown]
# #### Function calling is just like calling a waiter in a restaurent where in just like we call the waitor and provide the input as the food item and then waitor provide us with the food itself, like in a similar way we can call a function as well and can provide the input and can get the required output after calling the function only.

# %% [markdown]
# ## calling a Function --> Mention the name of the function and then provide the input

# %%
English_input = input('Enter your English word for getting it translated into Hindi')

translator(English_input)
# Out:
# The translator for Hello is Namaste

# %%
## Functions to convert English to Hindi

def translator_return(English_text):
    if English_text == 'Hello' or English_text == 'hello':
        Hindi_word = 'Namaste'

    elif English_text == 'Help' or English_text == 'help':
        Hindi_word = 'Madad'

    elif English_text == 'Required' or English_text == 'required':
        Hindi_word = 'Aavashyak'

    return Hindi_word

# %%
English_return_input = input('Enter your English word for getting it translated into Hindi')
Hindi_output = translator_return(English_return_input)
print(Hindi_output)
# Out:
# Namaste
