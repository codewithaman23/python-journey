# %% [markdown]
# # Kywords

# %% [markdown]
# Keywords are the reserved words which can be used as our variable name as they are having a reserved meaning already in python

# %%
list = 'Aman Singh'
print(list)
# Out:
# Aman Singh

# %%
tuple
# Out:
# tuple

# %%
 list
# Out:
# 'Aman Singh'

# %%
set
# Out:
# set
