# %% [markdown]
# # Data Sturcture in Python

# %% [markdown]
# Data sturcture in python are being used for storing the data in a structured format so that we can access the data and along with that we can perform all of the opperations with these data structures that we can perform in the case of databases as well like a crud (create, update, delete) operations.

# %% [markdown]
# # Types of data structure in python:

# %% [markdown]
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# # The different types of data structure differs on this basis that in which specific format we want to store our data
